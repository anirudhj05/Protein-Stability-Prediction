# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Dropout, Bidirectional, BatchNormalization
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, Callback
from sklearn.model_selection import train_test_split
from scipy.stats import spearmanr

# This step loads the datasets
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# Wrote a function to encode the AA sequences into integers
#It assigns each amino acid a unique integer.Essential for transforming categorical data to numerical form ML models 
#can process.
def encode_sequences(sequences):
    amino_acids = 'ARNDCQEGHILKMFPSTWYVX'
    aa_dict = {aa: idx + 1 for idx, aa in enumerate(amino_acids)}
    encoded = [[aa_dict.get(aa, 0) for aa in sequence] for sequence in sequences]
    return pad_sequences(encoded, maxlen=1000)

# Prepared the training and testing data
X_train = encode_sequences(train_data['sequence'])
y_train = train_data['target'].values
X_test = encode_sequences(test_data['sequence'])

# Splitting the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Model architecture: Bidirectional LSTMs with a custom attention mechanism.
#Inspired from https://github.com/kjs-design/CNN-BiLSTM-Attention-model/blob/master/Model/BiLSTM_Attention.py
#Changes made: Used Tensorflow instead of Pytorch and simplified the attention mechanism by using a Dense layer for 
#transforming LSTM outputs into attention weights and then applying these weights to the LSTM outputs.
#Used matrix operations directly to compute attention over the LSTM outputs.
def LSTM_model():
    inputs = Input(shape=(1000,))
    x = Embedding(input_dim=21 + 1, output_dim=128)(inputs) # Embedding layer
    x = Bidirectional(LSTM(256, return_sequences=True))(x)  # First LSTM layer
    x = Bidirectional(LSTM(int(256/2), return_sequences=True))(x) #Second LSTM layer
    
    # Simplified custom attention layer
    attention_data = Dense(1, activation='tanh')(x)
    attention_weights = tf.nn.softmax(attention_data, axis=1)
    context_vector = attention_weights * x
    context_vector = tf.reduce_sum(context_vector, axis=1)
    
    x = BatchNormalization()(context_vector) # Normalizing the batch data
    x = Dense(128, activation='relu')(x)  # Dense layer for further processing
    x = Dropout(0.5)(x) # Dropout to prevent overfitting
    outputs = Dense(1)(x) # Output layer
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
    return model

model = LSTM_model()
model.summary()

# wrote a function for Callback to monitor Spearman correlation during training
#Inspired from ChatGPT: https://chat.openai.com/share/ffb9e194-45f4-46b7-ba39-1d9bfec04caf
class SpearmanCorrelation(Callback):
    def on_epoch_end(self, epoch, logs=None):
        preds = model.predict(X_val)
        spearman_score, _ = spearmanr(y_val, preds)
        print(f"\nSpearman Correlation at epoch {epoch + 1}: {spearman_score:.4f}")
#Wrote a function for Learning rate scheduler to decrease the learning rate as training progresses
def adjust_learning_rate(epoch, lr):
    if epoch < 10:
        return lr
    return lr * tf.math.exp(-0.1)

checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True) # Checkpoint to save the best model
lr_scheduler = LearningRateScheduler(adjust_learning_rate) # Scheduler for learning rate adjustment

# Training the model
model.fit(X_train, y_train, epochs=100, batch_size=16, validation_data=(X_val, y_val), 
          callbacks=[SpearmanCorrelation(), checkpoint, lr_scheduler])

# Loading the best model saved during training
model = load_model('best_model.h5')

# Making predictions on the test set
predictions = model.predict(X_test)

# Saving the predictions to a CSV file
def save_predictions(test_ids, predictions):
    pd.DataFrame({'id': test_ids, 'target': predictions.flatten()}).to_csv('prediction.csv', index=False)

save_predictions(test_data['id'], predictions)
# Out:
# 2024-04-12 10:37:28.754283: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-12 10:37:43.108565: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-12 10:37:44.252292: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21324 MB memory:  -> device: 0, name: Quadro RTX 6000, pci bus id: 0000:3b:00.0, compute capability: 7.5
# 2024-04-12 10:37:44.253012: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 21324 MB memory:  -> device: 1, name: Quadro RTX 6000, pci bus id: 0000:5e:00.0, compute capability: 7.5
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1000)]       0           []
#
#  embedding (Embedding)          (None, 1000, 128)    2816        ['input_1[0][0]']
#
#  bidirectional (Bidirectional)  (None, 1000, 512)    788480      ['embedding[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 1000, 256)   656384      ['bidirectional[0][0]']
#  )
#
#  dense (Dense)                  (None, 1000, 1)      257         ['bidirectional_1[0][0]']
#
#  tf.nn.softmax (TFOpLambda)     (None, 1000, 1)      0           ['dense[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 1000, 256)    0           ['tf.nn.softmax[0][0]',
#                                                                   'bidirectional_1[0][0]']
#
#  tf.math.reduce_sum (TFOpLambda  (None, 256)         0           ['tf.math.multiply[0][0]']
#  )
#
#  batch_normalization (BatchNorm  (None, 256)         1024        ['tf.math.reduce_sum[0][0]']
#  alization)
#
#  dense_1 (Dense)                (None, 128)          32896       ['batch_normalization[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            129         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 1,481,986
# Trainable params: 1,481,474
# Non-trainable params: 512
# __________________________________________________________________________________________________
# Epoch 1/100
# 2024-04-12 10:37:51.868008: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 51/51 [==============================] - 5s 70ms/step
#
# Spearman Correlation at epoch 1: 0.3242
# 408/408 [==============================] - 72s 155ms/step - loss: 517.2255 - mae: 17.9091 - val_loss: 59.5791 - val_mae: 6.2808 - lr: 0.0010
# Epoch 2/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 2: 0.0119
# 408/408 [==============================] - 62s 152ms/step - loss: 145.0558 - mae: 9.5969 - val_loss: 68.6303 - val_mae: 6.8705 - lr: 0.0010
# Epoch 3/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 3: -0.0873
# 408/408 [==============================] - 62s 152ms/step - loss: 92.0811 - mae: 7.6090 - val_loss: 73.4194 - val_mae: 7.3317 - lr: 0.0010
# Epoch 4/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 4: 0.3644
# 408/408 [==============================] - 62s 152ms/step - loss: 67.4871 - mae: 6.5824 - val_loss: 21.8331 - val_mae: 3.7183 - lr: 0.0010
# Epoch 5/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 5: 0.3839
# 408/408 [==============================] - 62s 151ms/step - loss: 60.0629 - mae: 6.1941 - val_loss: 35.3208 - val_mae: 4.7826 - lr: 0.0010
# Epoch 6/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 6: 0.4869
# 408/408 [==============================] - 62s 152ms/step - loss: 58.7301 - mae: 6.1018 - val_loss: 19.8764 - val_mae: 3.5601 - lr: 0.0010
# Epoch 7/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 7: 0.4711
# 408/408 [==============================] - 62s 151ms/step - loss: 56.0977 - mae: 5.9510 - val_loss: 21.3790 - val_mae: 3.5867 - lr: 0.0010
# Epoch 8/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 8: 0.4882
# 408/408 [==============================] - 62s 151ms/step - loss: 54.1352 - mae: 5.8518 - val_loss: 42.6229 - val_mae: 5.1913 - lr: 0.0010
# Epoch 9/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 9: 0.4081
# 408/408 [==============================] - 62s 151ms/step - loss: 55.2792 - mae: 5.9250 - val_loss: 58.0279 - val_mae: 6.1984 - lr: 0.0010
# Epoch 10/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 10: 0.4731
# 408/408 [==============================] - 60s 148ms/step - loss: 53.5605 - mae: 5.8123 - val_loss: 27.4025 - val_mae: 3.9589 - lr: 0.0010
# Epoch 11/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 11: 0.0967
# 408/408 [==============================] - 62s 151ms/step - loss: 52.8988 - mae: 5.8026 - val_loss: 104.8521 - val_mae: 9.1718 - lr: 9.0484e-04
# Epoch 12/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 12: 0.4767
# 408/408 [==============================] - 62s 151ms/step - loss: 51.8966 - mae: 5.7219 - val_loss: 20.9738 - val_mae: 3.5563 - lr: 8.1873e-04
# Epoch 13/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 13: 0.5021
# 408/408 [==============================] - 60s 148ms/step - loss: 48.9521 - mae: 5.5722 - val_loss: 18.3501 - val_mae: 3.3471 - lr: 7.4082e-04
# Epoch 14/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 14: 0.5078
# 408/408 [==============================] - 60s 148ms/step - loss: 50.8823 - mae: 5.6718 - val_loss: 43.9319 - val_mae: 5.5911 - lr: 6.7032e-04
# Epoch 15/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 15: 0.5239
# 408/408 [==============================] - 62s 151ms/step - loss: 52.0849 - mae: 5.7361 - val_loss: 18.6217 - val_mae: 3.3102 - lr: 6.0653e-04
# Epoch 16/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 16: -0.0774
# 408/408 [==============================] - 62s 151ms/step - loss: 51.7276 - mae: 5.7553 - val_loss: 33.0147 - val_mae: 4.6452 - lr: 5.4881e-04
# Epoch 17/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 17: 0.3920
# 408/408 [==============================] - 62s 151ms/step - loss: 50.0994 - mae: 5.6352 - val_loss: 51.4082 - val_mae: 5.8470 - lr: 4.9659e-04
# Epoch 18/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 18: 0.4903
# 408/408 [==============================] - 62s 151ms/step - loss: 49.3650 - mae: 5.6029 - val_loss: 19.0617 - val_mae: 3.4617 - lr: 4.4933e-04
# Epoch 19/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 19: 0.4787
# 408/408 [==============================] - 62s 151ms/step - loss: 49.2025 - mae: 5.5821 - val_loss: 23.3753 - val_mae: 3.8437 - lr: 4.0657e-04
# Epoch 20/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 20: 0.5370
# 408/408 [==============================] - 62s 152ms/step - loss: 48.1890 - mae: 5.5656 - val_loss: 16.4993 - val_mae: 3.2285 - lr: 3.6788e-04
# Epoch 21/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 21: 0.5186
# 408/408 [==============================] - 62s 151ms/step - loss: 47.4303 - mae: 5.4792 - val_loss: 16.8547 - val_mae: 3.2691 - lr: 3.3287e-04
# Epoch 22/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 22: 0.5371
# 408/408 [==============================] - 60s 147ms/step - loss: 47.5058 - mae: 5.4738 - val_loss: 17.9744 - val_mae: 3.2480 - lr: 3.0119e-04
# Epoch 23/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 23: 0.5087
# 408/408 [==============================] - 60s 147ms/step - loss: 48.7735 - mae: 5.5538 - val_loss: 21.4780 - val_mae: 3.6671 - lr: 2.7253e-04
# Epoch 24/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 24: 0.5132
# 408/408 [==============================] - 60s 147ms/step - loss: 48.3513 - mae: 5.5269 - val_loss: 17.0044 - val_mae: 3.2352 - lr: 2.4660e-04
# Epoch 25/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 25: 0.4418
# 408/408 [==============================] - 62s 151ms/step - loss: 49.1997 - mae: 5.5538 - val_loss: 19.6864 - val_mae: 3.6896 - lr: 2.2313e-04
# Epoch 26/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 26: 0.5173
# 408/408 [==============================] - 62s 151ms/step - loss: 47.6539 - mae: 5.4755 - val_loss: 19.1354 - val_mae: 3.5050 - lr: 2.0190e-04
# Epoch 27/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 27: 0.5448
# 408/408 [==============================] - 62s 151ms/step - loss: 46.9865 - mae: 5.4734 - val_loss: 18.8908 - val_mae: 3.5667 - lr: 1.8268e-04
# Epoch 28/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 28: 0.5434
# 408/408 [==============================] - 62s 151ms/step - loss: 48.3526 - mae: 5.5324 - val_loss: 16.2926 - val_mae: 3.2399 - lr: 1.6530e-04
# Epoch 29/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 29: 0.4683
# 408/408 [==============================] - 62s 151ms/step - loss: 47.4231 - mae: 5.4739 - val_loss: 17.4781 - val_mae: 3.3307 - lr: 1.4957e-04
# Epoch 30/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 30: 0.5462
# 408/408 [==============================] - 62s 151ms/step - loss: 47.6597 - mae: 5.4915 - val_loss: 18.2489 - val_mae: 3.2806 - lr: 1.3534e-04
# Epoch 31/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 31: 0.5282
# 408/408 [==============================] - 62s 151ms/step - loss: 47.6810 - mae: 5.4771 - val_loss: 16.6936 - val_mae: 3.2978 - lr: 1.2246e-04
# Epoch 32/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 32: 0.5536
# 408/408 [==============================] - 60s 148ms/step - loss: 47.4721 - mae: 5.4602 - val_loss: 15.6224 - val_mae: 3.1208 - lr: 1.1080e-04
# Epoch 33/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 33: 0.5594
# 408/408 [==============================] - 62s 151ms/step - loss: 45.8097 - mae: 5.3708 - val_loss: 15.7566 - val_mae: 3.1547 - lr: 1.0026e-04
# Epoch 34/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 34: 0.5218
# 408/408 [==============================] - 60s 147ms/step - loss: 45.9802 - mae: 5.4047 - val_loss: 21.3735 - val_mae: 3.6160 - lr: 9.0718e-05
# Epoch 35/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 35: 0.5018
# 408/408 [==============================] - 60s 147ms/step - loss: 47.5222 - mae: 5.5223 - val_loss: 17.2923 - val_mae: 3.3604 - lr: 8.2085e-05
# Epoch 36/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 36: 0.5469
# 408/408 [==============================] - 62s 151ms/step - loss: 45.5303 - mae: 5.3542 - val_loss: 15.8155 - val_mae: 3.1082 - lr: 7.4273e-05
# Epoch 37/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 37: 0.5564
# 408/408 [==============================] - 60s 147ms/step - loss: 46.2595 - mae: 5.3899 - val_loss: 15.9248 - val_mae: 3.1130 - lr: 6.7205e-05
# Epoch 38/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 38: 0.5585
# 408/408 [==============================] - 62s 152ms/step - loss: 45.1671 - mae: 5.3172 - val_loss: 16.3428 - val_mae: 3.1168 - lr: 6.0810e-05
# Epoch 39/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 39: 0.5429
# 408/408 [==============================] - 62s 152ms/step - loss: 44.6180 - mae: 5.3212 - val_loss: 16.0497 - val_mae: 3.1885 - lr: 5.5023e-05
# Epoch 40/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 40: 0.5554
# 408/408 [==============================] - 60s 147ms/step - loss: 44.8094 - mae: 5.3013 - val_loss: 15.9151 - val_mae: 3.1168 - lr: 4.9787e-05
# Epoch 41/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 41: 0.5523
# 408/408 [==============================] - 62s 151ms/step - loss: 47.1849 - mae: 5.4662 - val_loss: 16.2710 - val_mae: 3.1336 - lr: 4.5049e-05
# Epoch 42/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 42: 0.5575
# 408/408 [==============================] - 62s 151ms/step - loss: 44.5984 - mae: 5.2993 - val_loss: 16.6183 - val_mae: 3.1275 - lr: 4.0762e-05
# Epoch 43/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 43: 0.5607
# 408/408 [==============================] - 62s 152ms/step - loss: 46.0615 - mae: 5.4092 - val_loss: 15.5566 - val_mae: 3.0799 - lr: 3.6883e-05
# Epoch 44/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 44: 0.5613
# 408/408 [==============================] - 62s 151ms/step - loss: 46.3695 - mae: 5.4168 - val_loss: 15.6972 - val_mae: 3.0854 - lr: 3.3373e-05
# Epoch 45/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 45: 0.5615
# 408/408 [==============================] - 62s 151ms/step - loss: 45.8736 - mae: 5.4208 - val_loss: 15.6970 - val_mae: 3.0776 - lr: 3.0197e-05
# Epoch 46/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 46: 0.5683
# 408/408 [==============================] - 62s 151ms/step - loss: 44.6680 - mae: 5.3147 - val_loss: 16.0283 - val_mae: 3.0932 - lr: 2.7324e-05
# Epoch 47/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 47: 0.5644
# 408/408 [==============================] - 62s 152ms/step - loss: 45.6803 - mae: 5.3680 - val_loss: 15.4204 - val_mae: 3.1248 - lr: 2.4723e-05
# Epoch 48/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 48: 0.5683
# 408/408 [==============================] - 62s 151ms/step - loss: 45.3850 - mae: 5.3618 - val_loss: 15.3058 - val_mae: 3.0723 - lr: 2.2371e-05
# Epoch 49/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 49: 0.5671
# 408/408 [==============================] - 62s 151ms/step - loss: 45.8501 - mae: 5.3855 - val_loss: 15.5060 - val_mae: 3.0757 - lr: 2.0242e-05
# Epoch 50/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 50: 0.5666
# 408/408 [==============================] - 60s 147ms/step - loss: 46.2093 - mae: 5.4057 - val_loss: 15.5296 - val_mae: 3.0680 - lr: 1.8316e-05
# Epoch 51/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 51: 0.5701
# 408/408 [==============================] - 62s 151ms/step - loss: 45.6446 - mae: 5.3545 - val_loss: 15.4654 - val_mae: 3.0633 - lr: 1.6573e-05
# Epoch 52/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 52: 0.5680
# 408/408 [==============================] - 60s 147ms/step - loss: 45.0480 - mae: 5.3170 - val_loss: 15.4743 - val_mae: 3.0709 - lr: 1.4996e-05
# Epoch 53/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 53: 0.5683
# 408/408 [==============================] - 62s 151ms/step - loss: 46.0438 - mae: 5.3949 - val_loss: 15.8209 - val_mae: 3.0849 - lr: 1.3569e-05
# Epoch 54/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 54: 0.5701
# 408/408 [==============================] - 62s 151ms/step - loss: 44.0036 - mae: 5.2659 - val_loss: 15.6243 - val_mae: 3.0700 - lr: 1.2277e-05
# Epoch 55/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 55: 0.5705
# 408/408 [==============================] - 62s 151ms/step - loss: 44.5230 - mae: 5.3168 - val_loss: 15.6658 - val_mae: 3.0711 - lr: 1.1109e-05
# Epoch 56/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 56: 0.5696
# 408/408 [==============================] - 62s 151ms/step - loss: 44.4934 - mae: 5.3140 - val_loss: 15.3315 - val_mae: 3.0628 - lr: 1.0052e-05
# Epoch 57/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 57: 0.5724
# 408/408 [==============================] - 62s 151ms/step - loss: 44.6281 - mae: 5.3006 - val_loss: 15.3263 - val_mae: 3.0599 - lr: 9.0953e-06
# Epoch 58/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 58: 0.5689
# 408/408 [==============================] - 62s 151ms/step - loss: 45.1797 - mae: 5.3284 - val_loss: 15.9408 - val_mae: 3.0903 - lr: 8.2297e-06
# Epoch 59/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 59: 0.5722
# 408/408 [==============================] - 62s 151ms/step - loss: 45.8919 - mae: 5.3751 - val_loss: 15.3504 - val_mae: 3.0614 - lr: 7.4466e-06
# Epoch 60/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 60: 0.5725
# 408/408 [==============================] - 60s 148ms/step - loss: 44.9614 - mae: 5.3217 - val_loss: 15.4947 - val_mae: 3.0624 - lr: 6.7379e-06
# Epoch 61/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 61: 0.5711
# 408/408 [==============================] - 62s 151ms/step - loss: 45.3533 - mae: 5.3593 - val_loss: 15.4873 - val_mae: 3.0658 - lr: 6.0967e-06
# Epoch 62/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 62: 0.5716
# 408/408 [==============================] - 62s 151ms/step - loss: 46.1655 - mae: 5.3737 - val_loss: 15.3676 - val_mae: 3.0621 - lr: 5.5165e-06
# Epoch 63/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 63: 0.5708
# 408/408 [==============================] - 60s 148ms/step - loss: 44.5479 - mae: 5.2986 - val_loss: 15.5334 - val_mae: 3.0697 - lr: 4.9916e-06
# Epoch 64/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 64: 0.5711
# 408/408 [==============================] - 62s 152ms/step - loss: 45.4582 - mae: 5.3612 - val_loss: 15.3592 - val_mae: 3.0637 - lr: 4.5166e-06
# Epoch 65/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 65: 0.5704
# 408/408 [==============================] - 60s 147ms/step - loss: 44.4537 - mae: 5.3009 - val_loss: 15.5052 - val_mae: 3.0704 - lr: 4.0868e-06
# Epoch 66/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 66: 0.5715
# 408/408 [==============================] - 60s 147ms/step - loss: 45.2938 - mae: 5.3869 - val_loss: 15.4164 - val_mae: 3.0626 - lr: 3.6979e-06
# Epoch 67/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 67: 0.5714
# 408/408 [==============================] - 62s 151ms/step - loss: 43.9429 - mae: 5.2412 - val_loss: 15.3491 - val_mae: 3.0617 - lr: 3.3460e-06
# Epoch 68/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 68: 0.5705
# 408/408 [==============================] - 62s 151ms/step - loss: 45.8257 - mae: 5.4045 - val_loss: 15.5343 - val_mae: 3.0689 - lr: 3.0275e-06
# Epoch 69/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 69: 0.5705
# 408/408 [==============================] - 62s 151ms/step - loss: 44.4046 - mae: 5.2894 - val_loss: 15.4673 - val_mae: 3.0678 - lr: 2.7394e-06
# Epoch 70/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 70: 0.5711
# 408/408 [==============================] - 62s 151ms/step - loss: 46.2803 - mae: 5.4341 - val_loss: 15.5318 - val_mae: 3.0657 - lr: 2.4787e-06
# Epoch 71/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 71: 0.5712
# 408/408 [==============================] - 62s 151ms/step - loss: 44.2560 - mae: 5.3075 - val_loss: 15.5486 - val_mae: 3.0674 - lr: 2.2429e-06
# Epoch 72/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 72: 0.5713
# 408/408 [==============================] - 62s 151ms/step - loss: 43.3745 - mae: 5.2487 - val_loss: 15.4527 - val_mae: 3.0649 - lr: 2.0294e-06
# Epoch 73/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 73: 0.5713
# 408/408 [==============================] - 60s 147ms/step - loss: 45.6794 - mae: 5.3761 - val_loss: 15.4559 - val_mae: 3.0637 - lr: 1.8363e-06
# Epoch 74/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 74: 0.5720
# 408/408 [==============================] - 62s 151ms/step - loss: 44.4080 - mae: 5.2861 - val_loss: 15.4229 - val_mae: 3.0596 - lr: 1.6616e-06
# Epoch 75/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 75: 0.5725
# 408/408 [==============================] - 60s 147ms/step - loss: 45.3778 - mae: 5.3558 - val_loss: 15.4357 - val_mae: 3.0600 - lr: 1.5034e-06
# Epoch 76/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 76: 0.5723
# 408/408 [==============================] - 62s 151ms/step - loss: 44.8159 - mae: 5.3282 - val_loss: 15.4404 - val_mae: 3.0609 - lr: 1.3604e-06
# Epoch 77/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 77: 0.5721
# 408/408 [==============================] - 60s 147ms/step - loss: 46.2957 - mae: 5.4110 - val_loss: 15.3719 - val_mae: 3.0602 - lr: 1.2309e-06
# Epoch 78/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 78: 0.5717
# 408/408 [==============================] - 62s 151ms/step - loss: 44.5689 - mae: 5.3337 - val_loss: 15.3912 - val_mae: 3.0624 - lr: 1.1138e-06
# Epoch 79/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 79: 0.5720
# 408/408 [==============================] - 60s 147ms/step - loss: 44.4691 - mae: 5.2886 - val_loss: 15.3646 - val_mae: 3.0603 - lr: 1.0078e-06
# Epoch 80/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 80: 0.5719
# 408/408 [==============================] - 62s 151ms/step - loss: 44.6031 - mae: 5.2966 - val_loss: 15.4454 - val_mae: 3.0615 - lr: 9.1188e-07
# Epoch 81/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 81: 0.5724
# 408/408 [==============================] - 62s 151ms/step - loss: 45.0092 - mae: 5.3587 - val_loss: 15.3964 - val_mae: 3.0604 - lr: 8.2510e-07
# Epoch 82/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 82: 0.5723
# 408/408 [==============================] - 60s 147ms/step - loss: 45.8018 - mae: 5.3455 - val_loss: 15.4623 - val_mae: 3.0623 - lr: 7.4658e-07
# Epoch 83/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 83: 0.5721
# 408/408 [==============================] - 62s 151ms/step - loss: 46.3183 - mae: 5.3839 - val_loss: 15.4435 - val_mae: 3.0626 - lr: 6.7554e-07
# Epoch 84/100
# 51/51 [==============================] - 4s 70ms/step
#
# Spearman Correlation at epoch 84: 0.5720
# 408/408 [==============================] - 62s 151ms/step - loss: 44.9581 - mae: 5.3539 - val_loss: 15.4730 - val_mae: 3.0626 - lr: 6.1125e-07
# Epoch 85/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 85: 0.5719
# 408/408 [==============================] - 62s 151ms/step - loss: 43.3948 - mae: 5.2253 - val_loss: 15.4356 - val_mae: 3.0614 - lr: 5.5308e-07
# Epoch 86/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 86: 0.5720
# 408/408 [==============================] - 62s 151ms/step - loss: 44.4515 - mae: 5.3112 - val_loss: 15.4358 - val_mae: 3.0614 - lr: 5.0045e-07
# Epoch 87/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 87: 0.5720
# 408/408 [==============================] - 60s 147ms/step - loss: 44.0754 - mae: 5.2729 - val_loss: 15.4569 - val_mae: 3.0616 - lr: 4.5283e-07
# Epoch 88/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 88: 0.5718
# 408/408 [==============================] - 62s 151ms/step - loss: 44.5856 - mae: 5.3022 - val_loss: 15.4651 - val_mae: 3.0630 - lr: 4.0973e-07
# Epoch 89/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 89: 0.5718
# 408/408 [==============================] - 62s 151ms/step - loss: 43.4054 - mae: 5.2551 - val_loss: 15.4608 - val_mae: 3.0623 - lr: 3.7074e-07
# Epoch 90/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 90: 0.5719
# 408/408 [==============================] - 62s 152ms/step - loss: 44.4759 - mae: 5.2944 - val_loss: 15.4544 - val_mae: 3.0622 - lr: 3.3546e-07
# Epoch 91/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 91: 0.5719
# 408/408 [==============================] - 60s 148ms/step - loss: 44.0762 - mae: 5.2875 - val_loss: 15.4386 - val_mae: 3.0619 - lr: 3.0354e-07
# Epoch 92/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 92: 0.5717
# 408/408 [==============================] - 62s 151ms/step - loss: 45.5022 - mae: 5.3638 - val_loss: 15.5028 - val_mae: 3.0638 - lr: 2.7465e-07
# Epoch 93/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 93: 0.5722
# 408/408 [==============================] - 60s 148ms/step - loss: 45.1292 - mae: 5.3321 - val_loss: 15.3931 - val_mae: 3.0603 - lr: 2.4852e-07
# Epoch 94/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 94: 0.5722
# 408/408 [==============================] - 62s 151ms/step - loss: 44.4808 - mae: 5.3296 - val_loss: 15.3796 - val_mae: 3.0597 - lr: 2.2487e-07
# Epoch 95/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 95: 0.5722
# 408/408 [==============================] - 60s 147ms/step - loss: 44.0424 - mae: 5.2947 - val_loss: 15.3562 - val_mae: 3.0593 - lr: 2.0347e-07
# Epoch 96/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 96: 0.5721
# 408/408 [==============================] - 60s 147ms/step - loss: 44.9566 - mae: 5.3622 - val_loss: 15.4490 - val_mae: 3.0606 - lr: 1.8410e-07
# Epoch 97/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 97: 0.5719
# 408/408 [==============================] - 62s 151ms/step - loss: 46.0626 - mae: 5.3958 - val_loss: 15.4681 - val_mae: 3.0616 - lr: 1.6659e-07
# Epoch 98/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 98: 0.5719
# 408/408 [==============================] - 60s 147ms/step - loss: 45.0991 - mae: 5.2965 - val_loss: 15.4565 - val_mae: 3.0619 - lr: 1.5073e-07
# Epoch 99/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 99: 0.5721
# 408/408 [==============================] - 62s 151ms/step - loss: 45.2436 - mae: 5.3638 - val_loss: 15.4516 - val_mae: 3.0610 - lr: 1.3639e-07
# Epoch 100/100
# 51/51 [==============================] - 4s 69ms/step
#
# Spearman Correlation at epoch 100: 0.5719
# 408/408 [==============================] - 62s 151ms/step - loss: 45.3187 - mae: 5.3544 - val_loss: 15.5085 - val_mae: 3.0634 - lr: 1.2341e-07
# 61/61 [==============================] - 6s 69ms/step
